# %% [markdown]
# # Melanoma TME (Tirosh et al.)

# %%
import scanpy as sc
import os
import pandas as pd
import numpy as np
import pickle as pkl
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.stats

sc.settings.verbosity = 3

# %%
# import sys
# sys.path.insert(0,'..')
import scmer

# %% [markdown]
# ## 0. Get your environment ready
#
# 1. Download data from https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE72056
# 2. Get your conda environment ready with scanpy and scmer
#    ```
#    > conda create -n py311_scmer python=3.11 jupyter git
#    > conda activate py311_scmer
#    > conda install -c conda-forge scanpy python-igraph leidenalg
#    > pip install git+https://github.com/KChen-lab/SCMER
#    > git clone https://github.com/KChen-lab/SCMER
#    ```
# 3. Run this script (`notebooks/melanoma-cpu.ipynb`)
# We also confirmed that python 3.10 works. Other versions >=3.7 and <3.10 should also work.
#
# Data Source: Tirosh I, Izar B, Prakadan SM, Wadsworth MH 2nd et al. Dissecting the multicellular ecosystem of metastatic melanoma by single-cell RNA-seq. Science 2016 Apr 8;352(6282):189-96.
#
# ## 1. Load and clean data
#
# ### 1.1 Preprocessing
#
# We first rename duplicate gene names.

# %%
data = pd.read_table("../data/GSE72056_melanoma_single_cell_revised_v2.txt.gz", header=0)
def dedup(x):
    d = {}
    r = []
    for i in x:
        if i in d:
            d[i] += 1
            r.append(i + '_' + str(d[i]))
            print(i, 'renamed to', r[-1])
        else:
            d[i] = 1
            r.append(i)
    return r

data['Cell'] = dedup(data['Cell'])

data = data.T

data.columns = data.loc["Cell"]
data.drop('Cell', inplace=True)
data
# Out:
# MARCH2 renamed to MARCH2_2
# MARCH1 renamed to MARCH1_2
# Cell                         tumor malignant(1=no,2=yes,0=unresolved)  \
# Cy72_CD45_H02_S758_comb       72.0                                1.0
# CY58_1_CD45_B02_S974_comb     58.0                                1.0
# Cy71_CD45_D08_S524_comb       71.0                                2.0
# Cy81_FNA_CD45_B01_S301_comb   81.0                                2.0
# Cy80_II_CD45_B07_S883_comb    80.0                                2.0
# ...                            ...                                ...
# CY75_1_CD45_CD8_7__S223_comb  75.0                                1.0
# CY75_1_CD45_CD8_1__S65_comb   75.0                                1.0
# CY75_1_CD45_CD8_1__S93_comb   75.0                                1.0
# CY75_1_CD45_CD8_1__S76_comb   75.0                                1.0
# CY75_1_CD45_CD8_7__S274_comb  75.0                                1.0
#
# Cell                         non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)  \
# Cy72_CD45_H02_S758_comb                                                     2.0
# CY58_1_CD45_B02_S974_comb                                                   1.0
# Cy71_CD45_D08_S524_comb                                                     0.0
# Cy81_FNA_CD45_B01_S301_comb                                                 0.0
# Cy80_II_CD45_B07_S883_comb                                                  0.0
# ...                                                                         ...
# CY75_1_CD45_CD8_7__S223_comb                                                1.0
# CY75_1_CD45_CD8_1__S65_comb                                                 1.0
# CY75_1_CD45_CD8_1__S93_comb                                                 1.0
# CY75_1_CD45_CD8_1__S76_comb                                                 1.0
# CY75_1_CD45_CD8_7__S274_comb                                                0.0
#
# Cell                         C9orf152   RPS11   ELMO2 CREB3L1 PNMA1     MMP2  \
# Cy72_CD45_H02_S758_comb           0.0  9.2172     0.0     0.0   0.0      0.0
# CY58_1_CD45_B02_S974_comb         0.0  8.3745     0.0     0.0   0.0      0.0
# Cy71_CD45_D08_S524_comb           0.0   9.313  2.1263     0.0   0.0  0.73812
# Cy81_FNA_CD45_B01_S301_comb       0.0  7.8876     0.0     0.0   0.0      0.0
# Cy80_II_CD45_B07_S883_comb        0.0  8.3291     0.0     0.0   0.0      0.0
# ...                               ...     ...     ...     ...   ...      ...
# CY75_1_CD45_CD8_7__S223_comb      0.0  5.4889     0.0     0.0   0.0      0.0
# CY75_1_CD45_CD8_1__S65_comb       0.0  4.9262  5.5296     0.0   0.0      0.0
# CY75_1_CD45_CD8_1__S93_comb       0.0  7.0958     0.0     0.0   0.0      0.0
# CY75_1_CD45_CD8_1__S76_comb       0.0   3.997     0.0     0.0   0.0      0.0
# CY75_1_CD45_CD8_7__S274_comb      0.0  3.9897     0.0     0.0   0.0      0.0
#
# Cell                          TMEM216  ...    GPLD1 SNORD115-39   RAB8A RXFP2  \
# Cy72_CD45_H02_S758_comb           0.0  ...  0.62667         0.0     0.0   0.0
# CY58_1_CD45_B02_S974_comb         0.0  ...   1.0545         0.0     0.0   0.0
# Cy71_CD45_D08_S524_comb           0.0  ...  0.99639         0.0  2.7634   0.0
# Cy81_FNA_CD45_B01_S301_comb       0.0  ...  0.23143         0.0  4.1937   0.0
# Cy80_II_CD45_B07_S883_comb     3.7949  ...      0.0         0.0  2.5705   0.0
# ...                               ...  ...      ...         ...     ...   ...
# CY75_1_CD45_CD8_7__S223_comb      0.0  ...   1.2962         0.0     0.0   0.0
# CY75_1_CD45_CD8_1__S65_comb       0.0  ...  0.99245         0.0     0.0   0.0
# CY75_1_CD45_CD8_1__S93_comb       0.0  ...  0.97516         0.0     0.0   0.0
# CY75_1_CD45_CD8_1__S76_comb       0.0  ...  0.49208         0.0     0.0   0.0
# CY75_1_CD45_CD8_7__S274_comb  0.29007  ...   1.0682         0.0     0.0   0.0
#
# Cell                           PCIF1 PIK3IP1  SNRPD2 SLC39A6    CTSC AQP7
# Cy72_CD45_H02_S758_comb          0.0  7.6069     0.0     0.0  2.6638  0.0
# CY58_1_CD45_B02_S974_comb        0.0     0.0     0.0     0.0  6.9901  0.0
# Cy71_CD45_D08_S524_comb       3.6782     0.0  3.9871  3.8777  1.6126  0.0
# Cy81_FNA_CD45_B01_S301_comb      0.0     0.0  5.2639   3.766  4.8417  0.0
# Cy80_II_CD45_B07_S883_comb       0.0     0.0  6.0824  1.7816  4.4607  0.0
# ...                              ...     ...     ...     ...     ...  ...
# CY75_1_CD45_CD8_7__S223_comb     0.0     0.0  6.0986     0.0  3.6464  0.0
# CY75_1_CD45_CD8_1__S65_comb   5.5465  3.7384     0.0     0.0  7.0004  0.0
# CY75_1_CD45_CD8_1__S93_comb      0.0     0.0     0.0     0.0  1.9615  0.0
# CY75_1_CD45_CD8_1__S76_comb      0.0     0.0     0.0     0.0  7.1918  0.0
# CY75_1_CD45_CD8_7__S274_comb  5.0081  6.7535  5.9313  5.2398  6.1588  0.0
#
# [4645 rows x 23689 columns]

# %% [markdown]
# We then separate metadata from gene expression and remove ERCC spike-ins.

# %%
obs = data[['tumor', 'malignant(1=no,2=yes,0=unresolved)', 'non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)']]
data.drop(['tumor', 'malignant(1=no,2=yes,0=unresolved)', 'non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)'], 
          axis=1, inplace=True)
print(*data.columns[data.columns.str.startswith('ERCC')], 'are dropped')
data = data.loc[:, data.columns.str.startswith('ERCC') == False]

obs
# Out:
# ERCC5 ERCC8 ERCC1 ERCC4 ERCC6L ERCC6L2 ERCC3 ERCC6 ERCC2 are dropped
# Cell                         tumor malignant(1=no,2=yes,0=unresolved)  \
# Cy72_CD45_H02_S758_comb       72.0                                1.0
# CY58_1_CD45_B02_S974_comb     58.0                                1.0
# Cy71_CD45_D08_S524_comb       71.0                                2.0
# Cy81_FNA_CD45_B01_S301_comb   81.0                                2.0
# Cy80_II_CD45_B07_S883_comb    80.0                                2.0
# ...                            ...                                ...
# CY75_1_CD45_CD8_7__S223_comb  75.0                                1.0
# CY75_1_CD45_CD8_1__S65_comb   75.0                                1.0
# CY75_1_CD45_CD8_1__S93_comb   75.0                                1.0
# CY75_1_CD45_CD8_1__S76_comb   75.0                                1.0
# CY75_1_CD45_CD8_7__S274_comb  75.0                                1.0
#
# Cell                         non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)
# Cy72_CD45_H02_S758_comb                                                     2.0
# CY58_1_CD45_B02_S974_comb                                                   1.0
# Cy71_CD45_D08_S524_comb                                                     0.0
# Cy81_FNA_CD45_B01_S301_comb                                                 0.0
# Cy80_II_CD45_B07_S883_comb                                                  0.0
# ...                                                                         ...
# CY75_1_CD45_CD8_7__S223_comb                                                1.0
# CY75_1_CD45_CD8_1__S65_comb                                                 1.0
# CY75_1_CD45_CD8_1__S93_comb                                                 1.0
# CY75_1_CD45_CD8_1__S76_comb                                                 1.0
# CY75_1_CD45_CD8_7__S274_comb                                                0.0
#
# [4645 rows x 3 columns]

# %%
pd.crosstab(obs['malignant(1=no,2=yes,0=unresolved)'], obs['non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)'])
# Out:
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)   0.0   1.0  2.0  \
# malignant(1=no,2=yes,0=unresolved)
# 0.0                                                             90    24    3
# 1.0                                                            416  2040  512
# 2.0                                                           1252     4    0
#
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)  3.0  4.0  5.0  \
# malignant(1=no,2=yes,0=unresolved)
# 0.0                                                             6    3    5
# 1.0                                                           119   62   56
# 2.0                                                             1    0    0
#
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)  6.0
# malignant(1=no,2=yes,0=unresolved)
# 0.0                                                             1
# 1.0                                                            51
# 2.0                                                             0

# %%
# Suppress SettingWithCopyWarning
import warnings
import pandas as pd
# from pandas.core.common import SettingWithCopyWarning
# warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# Rename cell types for better appearance

malignant_dict = ['unresolved', 'normal', 'malignant']
celltype_dict = ['bordercase', 'T', 'B', 'Macro', 'Endo', 'CAF', 'NK']
obs['tumor'] = obs['tumor'].apply(lambda x: 'Mel' + str(int(x)))
obs['malignant'] = obs['malignant(1=no,2=yes,0=unresolved)'].astype(int).apply(malignant_dict.__getitem__)
obs['celltype'] = obs['non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)'].astype(int).apply(celltype_dict.__getitem__)
obs['patient'] = data.index.str.split('-|_', regex=True).str[0].str[:4].str.lower()
obs.loc[obs['malignant'] == 'malignant', 'celltype'] = 'malignant'
# Out:
# C:\Users\lshh\AppData\Local\Temp\ipykernel_25920\3669031727.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs['tumor'] = obs['tumor'].apply(lambda x: 'Mel' + str(int(x)))
# C:\Users\lshh\AppData\Local\Temp\ipykernel_25920\3669031727.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs['malignant'] = obs['malignant(1=no,2=yes,0=unresolved)'].astype(int).apply(malignant_dict.__getitem__)
# C:\Users\lshh\AppData\Local\Temp\ipykernel_25920\3669031727.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs['celltype'] = obs['non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)'].astype(int).apply(celltype_dict.__getitem__)
# C:\Users\lshh\AppData\Local\Temp\ipykernel_25920\3669031727.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs['patient'] = data.index.str.split('-|_', regex=True).str[0].str[:4].str.lower()

# %% [markdown]
# ### 1.2 Create AnnData for scanpy

# %%
adata = sc.AnnData(data)
for i in obs.columns:
    adata.obs[i] = obs[i]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4645 × 23677
#     obs: 'tumor', 'malignant(1=no,2=yes,0=unresolved)', 'non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)', 'malignant', 'celltype', 'patient'

# %% [markdown]
# ## 2 Typical SCANPY analysis

# %% [markdown]
# ### 2.1 QC

# %%
sc.settings.set_figure_params(dpi=50, facecolor='white')
sc.pl.highest_expr_genes(adata, n_top=20)
# Out:
# normalizing counts per cell
#     finished (0:00:02)
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# No mitochonrial genes available, which is okay.

# %%
# sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts'], jitter=0.4, multi_panel=True)

# %%
# sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
# Out:
# filtered out 1397 genes that are detected in less than 3 cells

# %% [markdown]
# ### 2.2 Normalization, HVG Selection, and Scaling

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
# Out:
# normalizing counts per cell
#     finished (0:00:01)

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
# Out:
# extracting highly variable genes
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:220: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
#     finished (0:00:02)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
sc.pl.highly_variable_genes(adata)

# %%
adata.raw = adata

# %%
adata = adata[:, adata.var.highly_variable]

# %%
sc.pp.scale(adata, max_value=10)
# Out:
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\preprocessing\_simple.py:843: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4645 × 6219
#     obs: 'tumor', 'malignant(1=no,2=yes,0=unresolved)', 'non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)', 'malignant', 'celltype', 'patient', 'n_genes'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg'

# %% [markdown]
# ### 2.3 Dimensional Reduction

# %%
sc.tl.pca(adata, svd_solver='arpack')
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:04)

# %%
sc.pl.pca(adata, color=['malignant', 'celltype', 'tumor'])
# Out:
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=20)
sc.tl.umap(adata)
sc.pl.umap(adata, color=['malignant', 'celltype', 'tumor'])
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 20
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:06)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:05)
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ## 3. SCMER Feature Selection
#
# Each step contains 20 inner iterations. It can be seen that the algorithm converges in 40~60 iternations.
#
# As a rule of thumb, the loss should end up with 3.0~4.0.
# 0.0 is perfect but it needs many features.
# A loss greater than 4.0 usually mean that the manifold is not well retained.

# %%
model = scmer._umap_l1.UmapL1(lasso=5e-4, n_pcs=20, 
                              perplexity=30., use_beta_in_Q=True, n_threads=12, use_gpu=False) # , max_inner_iter=1, max_outer_iter=1
model.fit(adata.X, batches=adata.obs['patient'])
# Out:
# Batch cy53 with 143 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 2.406145
# Done. Elapsed time: 5.08 seconds. Total: 5.08 seconds.
# Batch cy58 with 142 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 1.691135
# Done. Elapsed time: 5.31 seconds. Total: 10.39 seconds.
# Batch cy59 with 70 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 2.324188
# Done. Elapsed time: 5.47 seconds. Total: 15.85 seconds.
# Batch cy60 with 226 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 1.837958
# Done. Elapsed time: 5.33 seconds. Total: 21.19 seconds.
# Batch cy65 with 63 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 2.537185
# Done. Elapsed time: 4.98 seconds. Total: 26.16 seconds.
# Batch cy67 with 95 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 2.069539
# Done. Elapsed time: 5.04 seconds. Total: 31.20 seconds.
# Batch cy71 with 89 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 2.163097
# Done. Elapsed time: 4.93 seconds. Total: 36.13 seconds.
# Batch cy72 with 181 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 1.589412
# Done. Elapsed time: 5.00 seconds. Total: 41.13 seconds.
# Batch cy74 with 147 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 1.785351
# Done. Elapsed time: 5.11 seconds. Total: 46.24 seconds.
# Batch cy75 with 254 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 1.518978
# Done. Elapsed time: 5.04 seconds. Total: 51.28 seconds.
# Batch cy78 with 131 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 1.500593
# Done. Elapsed time: 4.95 seconds. Total: 56.23 seconds.
# Batch cy79 with 896 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 1.165000
# Done. Elapsed time: 5.43 seconds. Total: 61.67 seconds.
# Batch cy80 with 480 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 1.593692
# Done. Elapsed time: 5.16 seconds. Total: 66.82 seconds.
# Batch cy81 with 205 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 1.740897
# Done. Elapsed time: 5.01 seconds. Total: 71.84 seconds.
# Batch cy82 with 84 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 2.673452
# Done. Elapsed time: 4.95 seconds. Total: 76.79 seconds.
# Batch cy84 with 159 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 2.190422
# Done. Elapsed time: 4.98 seconds. Total: 81.76 seconds.
# Batch cy88 with 351 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 1.580093
# Done. Elapsed time: 5.08 seconds. Total: 86.84 seconds.
# Batch cy89 with 475 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 1.391499
# Done. Elapsed time: 5.11 seconds. Total: 91.95 seconds.
# Batch cy94 with 364 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 1.623442
# Done. Elapsed time: 5.09 seconds. Total: 97.04 seconds.
# Batch moni with 52 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 2.561964
# Done. Elapsed time: 4.92 seconds. Total: 101.96 seconds.
# Batch ss2 with 38 instances.
# Calculating distance matrix and scaling factors...
# Computing pairwise distances...
# Using 12 threads...
# Mean value of sigma: 2.757611
# Done. Elapsed time: 5.01 seconds. Total: 106.97 seconds.
# Creating model without batches...
# Optimizing using OWLQN (because lasso is nonzero)...
# 0 loss (before this step): 4.448923587799072 Nonzero (after): 24 Elapsed time: 22.28 seconds. Total: 129.25 seconds.
# 1 loss (before this step): 1.3149878978729248 Nonzero (after): 24 Elapsed time: 26.33 seconds. Total: 155.58 seconds.
# 2 loss (before this step): 1.3149672746658325 Nonzero (after): 24 Elapsed time: 7.00 seconds. Total: 162.58 seconds.
# 3 loss (before this step): 1.3149672746658325 Nonzero (after): 24 Elapsed time: 6.86 seconds. Total: 169.43 seconds.
# 4 loss (before this step): 1.3149672746658325 Nonzero (after): 24 Elapsed time: 6.82 seconds. Total: 176.25 seconds.
# Final loss: 1.2745356559753418 Nonzero: 24 Elapsed time: 0.31 seconds. Total: 176.56 seconds.

# %% [markdown]
# Selected markers:

# %%
print(*adata.var_names[model.get_mask()])
# Out:
# CST7 HLA-DRA TMSB4X TFF2 ELK2AP CD79A IL7R ASF1B NKG7 KLRK1 MTRNR2L2 FOXP3 CDK1 HLA-DRB1 HLA-DRB5 CD2 IL32 CD3D CD8A HLA-DQA1 MS4A1 CCL4 CD3E HLA-DPA1

# %% [markdown]
# ## 4. Validation
#
# ### 4.1 PCA and UMAP validation
#
# The PCA and UMAP largely resemble the ones obtained from all genes.

# %%
new_adata = model.transform(adata)
sc.tl.pca(new_adata, svd_solver='arpack')
sc.pl.pca(new_adata, color=['malignant', 'celltype', 'tumor'])
sc.pp.neighbors(new_adata, n_pcs=10, use_rep="X_pca")
sc.tl.umap(new_adata)
sc.pl.umap(new_adata, color=['malignant', 'celltype', 'tumor'], frameon=False)
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=23
#     finished (0:00:00)
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\preprocessing\_pca.py:229: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.
#   adata.obsm['X_pca'] = X_pca
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:05)
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py311_scmer\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ### 4.2 Scatter Plot of the Selected Features

# %%
sc.settings.set_figure_params(dpi=50, facecolor='white')
sc.pl.umap(adata, color=adata.var_names[model.get_mask()], ncols=5, legend_loc="on data", legend_fontsize=8., color_map="inferno")

# %% [markdown]
# ## 5. Session Info

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.3
# scanpy      1.9.6
# -----
# PIL                         9.4.0
# anyio                       NA
# asttokens                   NA
# attr                        23.1.0
# attrs                       23.1.0
# babel                       2.11.0
# backcall                    0.2.0
# brotli                      1.0.9
# certifi                     2023.11.17
# cffi                        1.16.0
# charset_normalizer          2.0.4
# colorama                    0.4.6
# comm                        0.1.2
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.6.7
# decorator                   5.1.1
# defusedxml                  0.7.1
# executing                   0.8.3
# fastjsonschema              NA
# h5py                        3.9.0
# idna                        3.4
# igraph                      0.11.3
# ipykernel                   6.25.0
# ipywidgets                  8.0.4
# jedi                        0.18.1
# jinja2                      3.1.2
# joblib                      1.3.2
# json5                       NA
# jsonschema                  4.19.2
# jsonschema_specifications   NA
# jupyter_events              0.8.0
# jupyter_server              2.10.0
# jupyterlab_server           2.25.1
# kiwisolver                  1.4.5
# leidenalg                   0.10.1
# llvmlite                    0.41.1
# markupsafe                  2.1.1
# matplotlib                  3.8.2
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# mpmath                      1.3.0
# natsort                     8.4.0
# nbformat                    5.9.2
# nt                          NA
# numba                       0.58.1
# numpy                       1.26.2
# overrides                   NA
# packaging                   23.1
# pandas                      2.1.3
# parso                       0.8.3
# patsy                       0.5.4
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                3.10.0
# prometheus_client           NA
# prompt_toolkit              3.0.36
# psutil                      5.9.0
# pure_eval                   0.2.2
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.15.1
# pynndescent                 0.5.11
# pyparsing                   3.1.1
# pythoncom                   NA
# pythonjsonlogger            NA
# pytz                        2023.3.post1
# pywintypes                  NA
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.11.4
# scmer                       NA
# seaborn                     0.12.2
# send2trash                  NA
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.3.2
# sniffio                     1.2.0
# socks                       1.7.1
# stack_data                  0.2.0
# statsmodels                 0.14.0
# sympy                       1.12
# texttable                   1.7.0
# threadpoolctl               3.2.0
# torch                       2.1.1+cpu
# torchgen                    NA
# tornado                     6.3.3
# tqdm                        4.66.1
# traitlets                   5.7.1
# typing_extensions           NA
# umap                        0.5.5
# urllib3                     1.26.18
# wcwidth                     0.2.5
# websocket                   0.58.0
# win32api                    NA
# win32com                    NA
# win32con                    NA
# win32trace                  NA
# winerror                    NA
# yaml                        6.0.1
# zmq                         25.1.0
# zoneinfo                    NA
# -----
# IPython             8.15.0
# jupyter_client      8.6.0
# jupyter_core        5.5.0
# jupyterlab          4.0.8
# notebook            7.0.6
# -----
# Python 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]
# Windows-10-10.0.19045-SP0
# -----
# Session information updated at 2023-12-07 14:14
